# %% [markdown]
# <a href="https://colab.research.google.com/github/marcusguerra/Twitter_Scraper/blob/master/dataShow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import urllib.request

# %%
# !wget https://github.com/marcusguerra/Twitter_Scraper/raw/master/dados.csv
# Out:
# --2023-06-13 02:17:42--  https://github.com/marcusguerra/Twitter_Scraper/raw/master/dados.csv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/marcusguerra/Twitter_Scraper/master/dados.csv [following]
# --2023-06-13 02:17:43--  https://raw.githubusercontent.com/marcusguerra/Twitter_Scraper/master/dados.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3490436 (3.3M) [text/plain]
# Saving to: ‘dados.csv’
#
# dados.csv           100%[===================>]   3.33M  --.-KB/s    in 0.04s
#
# 2023-06-13 02:17:44 (84.8 MB/s) - ‘dados.csv’ saved [3490436/3490436]

# %%
df = pd.read_csv('dados.csv', delimiter=',')

# %%
def mostraImagem(link, imagem):
  image_url = link
  image_path = imagem
  urllib.request.urlretrieve(image_url, image_path)
  image = plt.imread(image_path)
  plt.figure(figsize=(10, 10))
  plt.imshow(image)
  plt.axis('off')
  plt.show()

# %%
df = pd.read_csv('dados.csv', delimiter=',')
print(df.columns)
# Out:
# Index(['tweet', 'dateTime', 'keyWord'], dtype='object')

# %% [markdown]
# #Dados:
#
# ##Total de cada palavra

# %%
keyword_counts = df['keyWord'].value_counts()
print(keyword_counts)
print("total = ", keyword_counts.sum())
# Out:
# amazonia                       1117
# queimadas                      1115
# meio ambiente                  1112
# biodiversidade                  893
# mst                             885
# agricultura                     735
# agropecuaria                    712
# ibama                           654
# garimpeiros                     646
# Sustentabilidade                584
# marco temporal                  578
# boiada                          454
# ministerio do meio ambiente     438
# indigenista                     427
# ruralistas                      408
# garimpo                         398
# pantanal                        392
# reforma agraria                 372
# agrotoxico                      345
# quilombolas                     330
# Desenvolvimento Sustentavel     287
# Florestal Amazonica             278
# agronegocio                     272
# mtst                            237
# desmatamento                    234
# latifundiario                   187
# ...

# %%
plt.figure(figsize=(8, 6))
plt.pie(keyword_counts, labels=keyword_counts.index, autopct='%1.1f%%')
plt.title('Keyword Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##Data mais antiga de cada palavra

# %%
oldest_dates = df.groupby('keyWord')['dateTime'].min()

# Print the oldest date for each keyword
for keyword, date in oldest_dates.items():
    print(f"Oldest date for '{keyword}': {date}")
# Out:
# Oldest date for 'Desenvolvimento Sustentavel': 2023-06-01 13:08:51.316109
# Oldest date for 'Florestal Amazonica': 2023-05-23 02:00:26.211065
# Oldest date for 'Sustentabilidade': 2023-05-29 10:55:43.085522
# Oldest date for 'agricultura': 2023-02-08 13:10:15.377520
# Oldest date for 'agronegocio': 2023-05-29 10:46:07.473715
# Oldest date for 'agropecuaria': 2023-04-14 13:10:15.224580
# Oldest date for 'agrotoxico': 2023-06-05 13:10:15.861302
# Oldest date for 'amazonia': 2023-05-26 13:10:15.352443
# Oldest date for 'boiada': 2023-06-08 13:10:15.366957
# Oldest date for 'desmatamento': 2023-06-02 13:10:15.947394
# Oldest date for 'garimpeiros': 2023-06-02 13:10:15.324791
# Oldest date for 'garimpo': 2023-06-05 13:10:15.001477
# Oldest date for 'ibama': 2023-05-29 13:10:15.062905
# Oldest date for 'indigenista': 2023-06-01 13:10:15.318530
# Oldest date for 'latifundiario': 2023-06-02 13:10:15.224959
# Oldest date for 'marco temporal': 2023-05-29 13:10:15.972366
# ...

# %% [markdown]
# #Tratamento dos Tweets:
# ##como os tweets ficam

# %%
mostraImagem("https://github.com/marcusguerra/Twitter_Scraper/raw/master/imagens/Ex1.PNG", "Ex1.PNG")

# %% [markdown]
# "Por conta de vontade superior, hoje focaremos em horta, flores, agroecologia e agricultura da abundancia, bem como experiencias estatais nesse sentido. youtube.com OS JEITOS QUE A VIDA ENCONTRA",2023-06-12 20:05:29.785295,agricultura

# %%
mostraImagem("https://github.com/marcusguerra/Twitter_Scraper/raw/master/imagens/Ex2.PNG", "Ex2.PNG")

# %% [markdown]
# "A Assembleia Legislativa do Amapa (Alap) se prepara para colocar em pauta a precariedade dos assentamentos rurais existentes no estado, e a baixa producao agricola oriunda dessas localidades. A Comissao de Agricultura e Abastecimento (CAB)blogderocha.com.br Junior Favacho propoe debate sobre a precariedade e a baixa producao agricola nos assentamentos do...A Assembleia Legislativa do Amapa (Alap) se prepara para colocar em pauta a precariedade dos assentamentos rurais existentes no estado, e a baixa producao ag",2023-06-12 20:05:29.785295,agricultura

# %%
mostraImagem("https://github.com/marcusguerra/Twitter_Scraper/raw/master/imagens/Ex3.PNG", "Ex3.PNG")

# %% [markdown]
# "Alarmar? Os meteorologistas lancam avisos de mau tempo, hoje, dia 12, por exemplo, foi mais um dia de danos significativos na agricultura no Interior norte e centro. Nao e onde a maioria da populacao vive, mas faz parte de Portugal, certo?",2023-06-12 20:05:29.782198,agricultura

# %%
mostraImagem("https://github.com/marcusguerra/Twitter_Scraper/raw/master/imagens/Ex4.PNG", "Ex4.PNG")

# %% [markdown]
# O horror comunista... Estao devastando nossa agricultura.. Nossa comida... Se preparem... Tomaram o Brasil e vamos perder nossa liberdade.,2023-06-12 20:05:29.785295,agricultura

# %% [markdown]
# ##Limpeza dos Tweets:

# %% [markdown]
# ###Lixos
#
# Qualquer lixo como: Imagens, Em resposta a, Comentar o Tweet, Foto quadrada do perfil , assim como o Nome do Usuário e seu @, são removidos.

# %%
mostraImagem("https://github.com/marcusguerra/Twitter_Scraper/raw/master/imagens/Ex5.PNG", "Ex5.PNG")

# %% [markdown]
# Tweet gerado:
# Foi o avanço tecnologico com a melhoria na agricultura se produz mais alimentos, no transporte se chega  a lugares inalcanceveis a única coisa que o capitalismo fez foi concentrar dinheiro na mão de bilionario enquanto como citei 1/9 passa fome e não é por falta de recurso.

# %% [markdown]
# ###Tweets que não tem a palavra chave
# A função de busca do twitter capta a palavra chave no nome de usuário da pessoa, assim como no @, o que não é relevante para os dados, logo eles são excluidos

# %%
mostraImagem("https://github.com/marcusguerra/Twitter_Scraper/raw/master/imagens/Ex6.PNG", "Ex6.PNG")

# %% [markdown]
# ###Tweets Repetidos/bots/spam
# o algoritmo tenta dar uma filtrada em spans/bots excluindo mensagens exatamente iguais, contudo ainda passam alguns spans que tem leves diferenças, existem outras 75 mensagens quase identicas a essas de baixo

# %%
mostraImagem("https://github.com/marcusguerra/Twitter_Scraper/raw/master/imagens/Ex7.PNG", "Ex7.PNG")
